# %%
import numpy as np
import matplotlib.pyplot as plt

eigHist04 = np.loadtxt('eigHist04', unpack = True)
plt.hist(eigHist04[0],bins =90, density = 1)
plt.xlabel('E',fontsize=16)
plt.ylabel('DOS',fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

plt.show()

eigHist08 = np.loadtxt('eigHist08', unpack = True)
plt.hist(eigHist08[0],bins =90, density = 1)
plt.xlabel('E',fontsize=16)
plt.ylabel('DOS',fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

plt.show()

eigHist10 = np.loadtxt('eigHist10', unpack = True)
plt.hist(eigHist10[0],bins =90, density = 1)
plt.xlabel('E',fontsize=16)
plt.ylabel('DOS',fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

plt.show()

eigHist15 = np.loadtxt('eigHist15', unpack = True)
plt.hist(eigHist15[0],bins =90, density = 1)
plt.xlabel('E',fontsize=16)
plt.ylabel('DOS',fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

plt.show()

eigHist20 = np.loadtxt('eigHist20', unpack = True)
plt.hist(eigHist20[0],bins =90, density = 1)
plt.xlabel('E',fontsize=16)
plt.ylabel('DOS',fontsize=16)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

plt.show()

# %%
eigHist15
# Out:
# array([[-0.751678,  0.021338,  0.02918 ,  0.425043,  0.425262,  0.428909,
#          0.429855,  0.435479,  0.437509,  0.444537,  0.44823 ,  0.456303,
#          0.462019,  0.470639,  0.478886,  0.487628,  0.498845,  0.507263,
#          0.521918,  0.529574,  0.548137,  0.554597,  0.577553,  0.58238 ,
#          0.610239,  0.612993,  0.6463  ,  0.646531,  0.683127,  0.685888,
#          0.722968,  0.72922 ,  0.766317,  0.776609,  0.813549,  0.828506,
#          0.865215,  0.885565,  0.922136,  0.94871 ,  0.985588,  1.01908 ,
#          1.057641,  1.096626,  1.141247,  1.141247,  1.14134 ,  1.14134 ,
#          1.141886,  1.142995,  1.142995,  1.143371,  1.143371,  1.145905,
#          1.145905,  1.14675 ,  1.14675 ,  1.149972,  1.149972,  1.151471,
#          1.151471,  1.155186,  1.155186,  1.157525,  1.157525,  1.161536,
#          1.161536,  1.164898,  1.164898,  1.169009,  1.169009,  1.170643,
#          1.173574,  1.173574,  1.177586,  1.177586,  1.183531,  1.183531,
# ...
